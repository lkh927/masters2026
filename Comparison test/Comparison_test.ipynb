# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# %load_ext autoreload
# %autoreload 1

# %aimport modeltest

# %%
# Parameter values
# Firm 1: U[0,1]
a1, b1 = 0, 1

sigma = 0.3
# Firm 2: U[a2,b2]
a2, b2 = -sigma, 1 + sigma

eps = 0.1
s = 0.25

# %%
sol_eps = modeltest.solve_equilibrium_o(eps,s)
print("Epsilon:", sol_eps)

sol_var = modeltest.solve_equilibrium_var(s, 
                                          a1, b1, a2, b2)
print("Variance:", sol_var)
# Out:
# Epsilon: {'p1': 0.5353620069352739, 'p2': 0.4873334833516168, 'converged': True, 'iterations': 2}
# Variance: {'p1': 0.9999940391390134, 'p2': 1.299995603496052, 'converged': True}
